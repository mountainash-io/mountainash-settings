# %%
from mountainash_settings import SettingsParameters
from mountainash_settings.auth.storage.providers import S3StorageAuthSettings, GCSStorageAuthSettings, AzureBlobStorageAuthSettings, AzureFilesStorageAuthSettings

from upath import UPath

s3configfile = [UPath("./../config/auth/storage/cloud/s3.yaml"), UPath("./../../mountainash-settings/config/auth/storage/cloud/s3.env")]
gcs_configfile = [UPath("./../config/auth/storage/cloud/gcs.yaml")]
azure_blob_configfile = [UPath("./../config/auth/storage/cloud/azure_blob.yaml")]
azure_files_configfile = [UPath("./../config/auth/storage/cloud/azure_file.yaml")]

sp_s3 = SettingsParameters.create(config_files=s3configfile)

# s3 = S3StorageAuthSettings(config_files=s3configfile)
s3 = S3StorageAuthSettings(settings_parameters=sp_s3)


# gcs = GCSStorageAuthSettings(config_files=gcs_configfile)
# azure_blob = AzureBlobStorageAuthSettings(config_files=azure_blob_configfile)
# azure_files = AzureFilesStorageAuthSettings(config_files=azure_files_configfile)


s3
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[4], line 14
#      11 sp_s3 = SettingsParameters.create(config_files=s3configfile)
#      13 # s3 = S3StorageAuthSettings(config_files=s3configfile)
# ---> 14 s3 = S3StorageAuthSettings(settings_parameters=sp_s3)
#      17 # gcs = GCSStorageAuthSettings(config_files=gcs_configfile)
#      18 # azure_blob = AzureBlobStorageAuthSettings(config_files=azure_blob_configfile)
#      19 # azure_files = AzureFilesStorageAuthSettings(config_files=azure_files_configfile)
#      22 s3
#
# File ~/mountainash-dev-local/.venv/lib/python3.12/site-packages/mountainash_settings/auth/storage/providers/cloud/s3.py:66, in S3StorageAuthSettings.__init__(self, config_files, _dummy, **kwargs)
#      62 def __init__(self,
#      63              config_files: Optional[str|UPath|List[str|UPath]|Tuple[str|UPath]] = None,
#      64              _dummy: Optional[bool] = False,
#      65              **kwargs) -> None:
# ---> 66     super().__init__(config_files=config_files, _dummy=_dummy, **kwargs)
#
# File ~/mountainash-dev-local/.venv/lib/python3.12/site-packages/mountainash_settings/auth/storage/base.py:75, in StorageAuthBase.__init__(self, config_files, settings_parameters, _dummy, **kwargs)
#      69 def __init__(self,
#      70              config_files: Optional[str|UPath|List[str|UPath]|Tuple[str|UPath]] = None,
#      71              settings_parameters: Optional[SettingsParameters] = None,
#      72              _dummy: Optional[bool] = False,
#      73              **kwargs) -> None:
# ---> 75     super().__init__(config_files=config_files,
#      76                      settings_parameters = settings_parameters,
#      77                      _dummy=_dummy,
#      78                      **kwargs)
#
# File ~/mountainash-dev-local/.venv/lib/python3.12/site-packages/mountainash_settings/base.py:68, in MountainAshBaseSettings.__init__(self, config_files, settings_parameters, _dummy, **kwargs)
#      65     self.model_config["toml_file"] = obj_config_files.toml_files or None
#      66     self.model_config["json_file"] = obj_config_files.json_files or None
# ---> 68 super().__init__(_case_sensitive=True,
#      69                     _env_prefix=            local_settings_params.env_prefix or None,
#      70                     _env_file=              obj_config_files.env_files or None,
#      71                     _env_file_encoding =    'utf-8',
#      72                     _env_ignore_empty =     True,
#      73                     _env_parse_none_str =   "None",
#      74                     _secrets_dir=           local_settings_params.secrets_dir or None,
#      75                 )
#      77 if not _dummy:
#      78
#      79     #Update all vals from valid kwargs
#      80     self.update_settings_from_dict(local_settings_params.kwargs)
#
# File ~/mountainash-dev-local/.venv/lib/python3.12/site-packages/pydantic_settings/main.py:167, in BaseSettings.__init__(__pydantic_self__, _case_sensitive, _nested_model_default_partial_update, _env_prefix, _env_file, _env_file_encoding, _env_ignore_empty, _env_nested_delimiter, _env_parse_none_str, _env_parse_enums, _cli_prog_name, _cli_parse_args, _cli_settings_source, _cli_parse_none_str, _cli_hide_none_type, _cli_avoid_json, _cli_enforce_required, _cli_use_class_docs_for_groups, _cli_exit_on_error, _cli_prefix, _cli_flag_prefix_char, _cli_implicit_flags, _cli_ignore_unknown_args, _secrets_dir, **values)
#     139 def __init__(
#     140     __pydantic_self__,
#     141     _case_sensitive: bool | None = None,
#    (...)
#     165 ) -> None:
#     166     # Uses something other than `self` the first arg to allow "self" as a settable attribute
# --> 167     super().__init__(
#     168         **__pydantic_self__._settings_build_values(
#     169             values,
#     170             _case_sensitive=_case_sensitive,
#     171             _nested_model_default_partial_update=_nested_model_default_partial_update,
#     172             _env_prefix=_env_prefix,
#     173             _env_file=_env_file,
#     174             _env_file_encoding=_env_file_encoding,
#     175             _env_ignore_empty=_env_ignore_empty,
#     176             _env_nested_delimiter=_env_nested_delimiter,
#     177             _env_parse_none_str=_env_parse_none_str,
#     178             _env_parse_enums=_env_parse_enums,
#     179             _cli_prog_name=_cli_prog_name,
#     180             _cli_parse_args=_cli_parse_args,
#     181             _cli_settings_source=_cli_settings_source,
#     182             _cli_parse_none_str=_cli_parse_none_str,
#     183             _cli_hide_none_type=_cli_hide_none_type,
#     184             _cli_avoid_json=_cli_avoid_json,
#     185             _cli_enforce_required=_cli_enforce_required,
#     186             _cli_use_class_docs_for_groups=_cli_use_class_docs_for_groups,
#     187             _cli_exit_on_error=_cli_exit_on_error,
#     188             _cli_prefix=_cli_prefix,
#     189             _cli_flag_prefix_char=_cli_flag_prefix_char,
#     190             _cli_implicit_flags=_cli_implicit_flags,
#     191             _cli_ignore_unknown_args=_cli_ignore_unknown_args,
#     192             _secrets_dir=_secrets_dir,
#     193         )
#     194     )
#
# File ~/mountainash-dev-local/.venv/lib/python3.12/site-packages/pydantic/main.py:212, in BaseModel.__init__(self, **data)
#     210 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     211 __tracebackhide__ = True
# --> 212 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     213 if self is not validated_self:
#     214     warnings.warn(
#     215         'A custom validator is returning a value other than `self`.\n'
#     216         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     217         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     218         category=None,
#     219     )
#
# ValidationError: 2 validation errors for S3StorageAuthSettings
# REGION
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.9/v/missing
# BUCKET
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.9/v/missing

# %%
from mountainash_settings.auth.database.providers import SQLiteAuthSettings, DuckDBAuthSettings,MSSQLAuthSettings,  MySQLAuthSettings, PostgreSQLAuthSettings, BigQueryAuthSettings, RedshiftAuthSettings, SnowflakeAuthSettings
from mountainash_settings.auth.database.providers.sql import mssql


duckdb_configfile = [UPath("./../config/auth/databases/file/duckdb.yaml")]
sqlite_configfile = [UPath("./../config/auth/databases/file/sqlite.yaml")]
mssql_configfile = [UPath("./../config/auth/databases/sql/mssql.yaml")]
mysql_configfile = [UPath("./../config/auth/databases/sql/mysql.yaml")]
postgresql_configfile = [UPath("./../config/auth/databases/sql/postgresql.yaml")]
biqquery_configfile = [UPath("./../config/auth/databases/cloud/bigquery.yaml")]
redshift_configfile = [UPath("./../config/auth/databases/cloud/redshift.yaml")]
snowflake_configfile = [UPath("./../config/auth/databases/cloud/snowflake.yaml")]



duckdb_auth = DuckDBAuthSettings(duckdb_configfile)
sqlite_auth = SQLiteAuthSettings(sqlite_configfile)
mssql_auth = MSSQLAuthSettings(mssql_configfile)
mysql_auth = MySQLAuthSettings(mysql_configfile)
postgresql_auth = PostgreSQLAuthSettings(postgresql_configfile)
bigquery_auth = BigQueryAuthSettings(biqquery_configfile, )
redshift_auth = RedshiftAuthSettings(redshift_configfile)
snowflake_auth = SnowflakeAuthSettings(snowflake_configfile)


mssql_auth.PROVIDER_TYPE

# %%
from mountainash_settings.auth.secrets.providers import AWSSecretsSettings, AzureKeyVaultSettings, GCPSecretsSettings, LocalSecretsSettings
from upath import UPath

# duckdb_configfile = [UPath("./../config/auth/databases/file/duckdb.yaml")]

aws_secret_auth = AWSSecretsSettings()
azurekv_secret_auth = AzureKeyVaultSettings()
gcp_secret_auth = GCPSecretsSettings()
local_secret_auth = LocalSecretsSettings()
